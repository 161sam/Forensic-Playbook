# %%
# Guarded Setup
DRY_RUN = True
from notebooks._utils.common import *
CLI_OK = shell_available('forensic-cli')
LAB_ID = '90_reporting_and_codex_mcp_exercise'
LAB_ROOT = lab_root(LAB_ID)
print(f'CLI available: {CLI_OK}')
print(f'Artifacts root: {LAB_ROOT}')

# %% [markdown]
# # Exercise · Reporting & Codex/MCP
#
# Complete the TODO sections to render a report and document Codex/MCP
# confirm-gates.

# %% [markdown]
# ## 1. Synthetic Report Data
# Run the helper cell to prepare deterministic report content.

# %%
from forensic.modules.reporting.exporter import export_report, get_pdf_renderer, export_pdf

REPORT_DIR = LAB_ROOT / 'reports'
REPORT_DIR.mkdir(parents=True, exist_ok=True)
REPORT_TS = _ts()

report_data = {
    'case': {'case_id': 'CASE-LAB-90', 'name': 'Notebook Investigation Demo', 'investigator': 'Notebook Analyst'},
    'executive_summary': {'timeline': 'Beacon contained within 15 minutes.'},
    'findings': [
        {'title': 'Router Workflow', 'details': 'Router export analysed successfully.', 'severity': 'medium'},
        {'title': 'IoC Matches', 'details': 'Indicators detected in firewall and beacon logs.', 'severity': 'high'},
    ],
    'timeline': {'events': [{'ts': '2024-03-01T12:03:12Z', 'event': 'Firewall block'}, {'ts': '2024-03-01T12:05:44Z', 'event': 'Analyst SSH login'}]},
}

json_dump_sorted(report_data, LAB_ROOT / f'{REPORT_TS}_report_data.json')
report_data

# %% [markdown]
# ## 2. TODO · Generate HTML Report
# Use `export_report` to create an HTML report inside `REPORT_DIR`. Save the path
# in `html_path` for later checkpoints.

# %%
# TODO: render HTML report using export_report and store the resulting Path in html_path.
raise NotImplementedError('Generate the HTML report output.')

# %% [markdown]
# ## 3. TODO · PDF Guard
# Check `get_pdf_renderer()`. If a renderer is available, convert the HTML report
# and capture the PDF path. Otherwise store a guard message.

# %%
# TODO: populate pdf_status with renderer information and optional pdf_path.
raise NotImplementedError('Implement the optional PDF guard logic.')

# %% [markdown]
# ## 4. TODO · Confirm-Gate Policy
# Load the first few lines of `forensic/mcp/prompts/forensic_mode.txt` and define
# `confirm_gate_policy` describing when Codex should request analyst approval.

# %%
# TODO: read the forensic-mode prompt and craft a confirm gate policy dictionary.
raise NotImplementedError('Describe the confirm-gate policy for Codex/MCP.')

# %% [markdown]
# ### Checkpoint
# Assert the presence of the HTML report and preview objects once finished.

# %%
# Example checkpoint (replace once TODOs are complete)
raise NotImplementedError('Add checkpoint assertions for generated artefacts.')
