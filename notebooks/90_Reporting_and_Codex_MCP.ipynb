# %% [markdown]
# # 90 · Reporting & MCP/Codex
#
# Generate HTML reports (always) and, when available, PDF (optional). Expose MCP tools and run a local adapter task (tolerant if missing).

# %%
# HTML report via CLI (tolerant). Uses synthesized artifacts from previous labs.
import shutil, subprocess
from pathlib import Path

WORKSPACE = Path.cwd() / "lab_workspace"
CASE = "lab_demo_case"
OUT = WORKSPACE / "out"
OUT.mkdir(exist_ok=True)

if shutil.which("forensic-cli"):
    subprocess.run(["forensic-cli","--workspace",str(WORKSPACE),
                    "report","generate","--case",CASE,"--fmt","html",
                    "--out", str(OUT / "report.html")], check=False)
    print("Report (html) expected at:", OUT / "report.html")
else:
    print("forensic-cli not found — creating a placeholder HTML to illustrate.")
    (OUT / "report.html").write_text("<html><body><h1>Report Placeholder</h1></body></html>")
    print("Wrote:", OUT / "report.html")

# %% [markdown]
# ### MCP/Codex (guarded, dry-run-first)

# %%
import shutil, subprocess
from pathlib import Path
WORKSPACE = Path.cwd() / "lab_workspace"

if shutil.which("forensic-cli"):
    subprocess.run(["forensic-cli","--workspace",str(WORKSPACE),
                    "codex","install","--dry-run"], check=False)
    subprocess.run(["forensic-cli","--workspace",str(WORKSPACE),
                    "codex","start","--foreground","--dry-run"], check=False)
    subprocess.run(["forensic-cli","--workspace",str(WORKSPACE),
                    "mcp","expose"], check=False)
else:
    print("Codex/MCP demo skipped — CLI not available in this environment.")
